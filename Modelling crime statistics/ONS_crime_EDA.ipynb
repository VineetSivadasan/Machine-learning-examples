# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import all three datasets and turn them into pandas dataframes 
df_crime = pd.read_csv('On_Street_Crime_In_Camden.csv')
df_ward_atlas = pd.read_csv('ward-atlas-data.csv', encoding= 'unicode_escape')  #non-ascii characters in the csv that can not be encoded/decoded hence must use unicode escape
df_ward_profile = pd.read_csv('ward-profiles-excel-version.csv', encoding= 'unicode_escape')

# %%
df_crime.head()
# Out:
#                 Category  Street ID                   Street Name  Context  \
# 0            Other theft    1489515         Kings Cross (station)      NaN
# 1  Anti-social behaviour     960522    On or near Wellesley Place      NaN
# 2  Theft from the person     965233        On or near Avenue Road      NaN
# 3  Anti-social behaviour     960974  On or near Birkenhead Street      NaN
# 4                  Drugs     972275   On or near Oakeshott Avenue      NaN
#
#                                 Outcome Category            Outcome Date  \
# 0                      Status update unavailable  08/01/2017 12:00:00 AM
# 1                                            NaN                     NaN
# 2  Investigation complete; no suspect identified  08/01/2015 12:00:00 AM
# 3                                            NaN                     NaN
# 4      Offender given a drugs possession warning  06/01/2015 12:00:00 AM
#
#                     Service Location Subtype        ID  \
# 0  British Transport Police          Station  64777250
# 1              Police Force              NaN  51520755
# 2              Police Force              NaN  42356413
# 3              Police Force              NaN  59431385
# 4              Police Force              NaN  41931981
#
#                                        Persistent ID                   Epoch  \
# 0                                                NaN  04/01/2017 12:00:00 AM
# 1                                                NaN  09/01/2016 12:00:00 AM
# 2  915131bf174019fd2fcf5aa4af305f7b2b34a763d8fcb0...  07/01/2015 12:00:00 AM
# 3                                                NaN  08/01/2017 12:00:00 AM
# 4  bd5bef6ee7b3711e69ecfc40c1c256d45336f23aeda337...  06/01/2015 12:00:00 AM
#
#    Ward Code                   Ward Name    Easting   Northing  Longitude  \
# 0  E05000143  St Pancras and Somers Town  530277.37  183101.39  -0.123189
# 1  E05000143  St Pancras and Somers Town  529707.23  182682.77  -0.131558
# 2  E05000144               Swiss Cottage  526716.88  184227.86  -0.174124
# 3  E05000141                King's Cross  530390.22  182860.71  -0.121652
# 4  E05000137                    Highgate  528335.87  186805.94  -0.149851
#
#     Latitude                                   Spatial Accuracy Last Uploaded  \
# 0  51.531800  This is only an approximation of where the cri...    11/07/2018
# 1  51.528169  This is only an approximation of where the cri...    11/07/2018
# 2  51.542741  This is only an approximation of where the cri...    05/05/2016
# 3  51.529611  This is only an approximation of where the cri...    03/11/2017
# 4  51.565544  This is only an approximation of where the cri...    21/08/2015
#
#                  Location
# 0    (51.5318, -0.123189)
# 1  (51.528169, -0.131558)
# 2  (51.542741, -0.174124)
# 3  (51.529611, -0.121652)
# 4  (51.565544, -0.149851)

# %%
# Look at the shape of the crime dataset and the types of data
df_crime.shape, df_crime.dtypes
# Out:
# ((285107, 20),
#  Category             object
#  Street ID             int64
#  Street Name          object
#  Context             float64
#  Outcome Category     object
#  Outcome Date         object
#  Service              object
#  Location Subtype     object
#  ID                    int64
#  Persistent ID        object
#  Epoch                object
#  Ward Code            object
#  Ward Name            object
#  Easting             float64
#  Northing            float64
#  Longitude           float64
#  Latitude            float64
#  Spatial Accuracy     object
#  Last Uploaded        object
#  Location             object
#  dtype: object)

# %%
#check to see if there are any NaN values in the dataset
checking_NaN = df_crime.isnull().values.any() 
checking_NaN
# Out:
# True

# %%
#locate rows where null values appear
NaN_rows = df_crime[df_crime.isnull().any(axis=1)]  
NaN_rows.shape
# Out:
# (285107, 20)

# %%
#locate columns where null values appear
NaN_columns = df_crime.isna().any()
NaN_columns
# Out:
# Category            False
# Street ID           False
# Street Name         False
# Context              True
# Outcome Category     True
# Outcome Date         True
# Service             False
# Location Subtype     True
# ID                  False
# Persistent ID        True
# Epoch               False
# Ward Code           False
# Ward Name           False
# Easting             False
# Northing            False
# Longitude           False
# Latitude            False
# Spatial Accuracy    False
# Last Uploaded       False
# Location            False
# dtype: bool

# %%
#find out how many rows in 'Context' column has NaN values
context_nan = df_crime.Context.isnull().values.ravel().sum()
context_nan
# Out:
# 285107

# %%
#Given that all values in 'Context' are NaN values, drop this column
df_crime.drop(['Context'], axis=1, inplace=True)

# %%
#Given that 'Location' is just longitude and latitude values, drop this column
df_crime.drop(['Location'], axis=1, inplace=True)

# %%
#'Spatial Accuracy' doesn't give any useful information hence drop this column
df_crime.drop(['Spatial Accuracy'], axis=1, inplace=True)

# %%
df_crime.shape
# Out:
# (285107, 17)

# %%
#find out how many rows in 'Outcome Category' column has NaN values
outcome_cat_nan = df_crime['Outcome Category'].isnull().values.ravel().sum()
outcome_cat_nan
# Out:
# 67292

# %%
#find out how many rows in 'Context' column has NaN values
outcome_date_nan = df_crime['Outcome Date'].isnull().values.ravel().sum()
outcome_date_nan
# Out:
# 67292

# %%
#find out how many rows in 'Context' column has NaN values
location_nan = df_crime['Location Subtype'].isnull().values.ravel().sum()
location_nan
# Out:
# 269410

# %%
#find out how many rows in 'Context' column has NaN values
persistent_nan = df_crime['Persistent ID'].isnull().values.ravel().sum()
persistent_nan
# Out:
# 82519

# %%
#describe the Epoch column
df_crime['Epoch'].describe()
# Out:
# count                     285107
# unique                        76
# top       03/01/2019 12:00:00 AM
# freq                        4694
# Name: Epoch, dtype: object

# %% [markdown]
# # Let's look at the numbers of crimes committed across London for the time span of the dataset

# %%
#introduce a count of 1 for each crime 
df_crime['count'] = 1

# %%
df_crime.dtypes
# Out:
# Category             object
# Street ID             int64
# Street Name          object
# Outcome Category     object
# Outcome Date         object
# Service              object
# Location Subtype     object
# ID                    int64
# Persistent ID        object
# Epoch                object
# Ward Code            object
# Ward Name            object
# Easting             float64
# Northing            float64
# Longitude           float64
# Latitude            float64
# Last Uploaded        object
# count                 int64
# dtype: object

# %%
# Sum crimes by monthly date over the full dataset time period
total_crimes_bydate = df_crime.groupby(['Epoch']).sum()      #sum 'count' number of crimes by date
total_crimes_bydate.drop(['Street ID', 'ID', 'Easting', 'Northing', 'Longitude','Latitude'], axis=1, inplace=True)     #remove all other columns
total_crimes_bydate['date'] = total_crimes_bydate.index        #create another column for the date, called date
total_crimes_bydate
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_28380\3857339063.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_crimes_bydate = df_crime.groupby(['Epoch']).sum()      #sum 'count' number of crimes by date
#                         count                    date
# Epoch
# 01/01/2015 12:00:00 AM   3111  01/01/2015 12:00:00 AM
# 01/01/2016 12:00:00 AM   3244  01/01/2016 12:00:00 AM
# 01/01/2017 12:00:00 AM   3073  01/01/2017 12:00:00 AM
# 01/01/2018 12:00:00 AM   3802  01/01/2018 12:00:00 AM
# 01/01/2019 12:00:00 AM   4114  01/01/2019 12:00:00 AM
# ...                       ...                     ...
# 12/01/2016 12:00:00 AM   3420  12/01/2016 12:00:00 AM
# 12/01/2017 12:00:00 AM   3524  12/01/2017 12:00:00 AM
# 12/01/2018 12:00:00 AM   4057  12/01/2018 12:00:00 AM
# 12/01/2019 12:00:00 AM   4240  12/01/2019 12:00:00 AM
# 12/01/2020 12:00:00 AM   3049  12/01/2020 12:00:00 AM
#
# [76 rows x 2 columns]

# %%
#change the date format in 'Epoch' column and sort values in month order
total_crimes_bydate['date'] = pd.to_datetime(total_crimes_bydate['date']).dt.date
total_crimes_bydate['date'] = pd.to_datetime(total_crimes_bydate['date']).dt.strftime('%d-%m-%Y')
total_crimes_bydate['date'] = pd.to_datetime(total_crimes_bydate.date)
total_crimes_bydate = total_crimes_bydate.sort_values(by = 'date')
total_crimes_bydate
# Out:
#                         count       date
# Epoch
# 01/01/2015 12:00:00 AM   3111 2015-01-01
# 02/01/2015 12:00:00 AM   3028 2015-02-01
# 03/01/2015 12:00:00 AM   3412 2015-03-01
# 04/01/2015 12:00:00 AM   3399 2015-04-01
# 05/01/2015 12:00:00 AM   3602 2015-05-01
# ...                       ...        ...
# 12/01/2020 12:00:00 AM   3049 2020-12-01
# 01/01/2021 12:00:00 AM   2691 2021-01-01
# 02/01/2021 12:00:00 AM   2746 2021-02-01
# 03/01/2021 12:00:00 AM   3128 2021-03-01
# 04/01/2021 12:00:00 AM   3170 2021-04-01
#
# [76 rows x 2 columns]

# %%
# plot the total number of crimes committed in London over the full 7 year period given in the dataset
plt.figure()
plt.plot(total_crimes_bydate['date'], total_crimes_bydate['count'])
plt.xlabel("date")
plt.ylabel("no.of crimes committed")
plt.title("crimes across London")
# Out:
# Text(0.5, 1.0, 'crimes across London')

# %% [markdown]
# # Let's look at the categories of crimes

# %%
#describe the category column
df_crime['Category'].describe()
# Out:
# count                    285107
# unique                       14
# top       Anti-social behaviour
# freq                      67292
# Name: Category, dtype: object

# %%
#get all the unique categories of crime and the 'size' i.e. number of categories
C = len(df_crime['Category'].unique())
C, df_crime['Category'].unique()
# Out:
# (14,
#  array(['Other theft', 'Anti-social behaviour', 'Theft from the person',
#         'Drugs', 'Violence and sexual offences', 'Vehicle crime',
#         'Possession of weapons', 'Burglary', 'Robbery', 'Public order',
#         'Shoplifting', 'Other crime', 'Criminal damage and arson',
#         'Bicycle theft'], dtype=object))

# %%
#create another category called 'category encoded' which contains the encoded crime categories. The coding of labels is done in alphabetical order
df_crime['Category encoded'] = df_crime['Category'].astype('category').cat.codes    #The crime labels in 'Category' are coded from 0 to 13 in alphabetical order

#to get the labels from the coded crime categories
c = df_crime.Category.astype('category') #create a new variable 'c', which is just the 'Category' column from the crime dataframe, as a category
d = dict(enumerate(c.cat.categories )) #build a dictionary, 'd' of all the labels from 'c' with each one numbered in alphabetical order from 0 to 13
#df_crime.dtypes, df_crime, d

# %%
c
# Out:
# 0                          Other theft
# 1                Anti-social behaviour
# 2                Theft from the person
# 3                Anti-social behaviour
# 4                                Drugs
#                       ...
# 285102           Theft from the person
# 285103                   Bicycle theft
# 285104           Theft from the person
# 285105    Violence and sexual offences
# 285106           Anti-social behaviour
# Name: Category, Length: 285107, dtype: category
# Categories (14, object): ['Anti-social behaviour', 'Bicycle theft', 'Burglary', 'Criminal damage and arson', ..., 'Shoplifting', 'Theft from the person', 'Vehicle crime', 'Violence and sexual offences']

# %%
c.cat

# %%
d
# Out:
# {0: 'Anti-social behaviour',
#  1: 'Bicycle theft',
#  2: 'Burglary',
#  3: 'Criminal damage and arson',
#  4: 'Drugs',
#  5: 'Other crime',
#  6: 'Other theft',
#  7: 'Possession of weapons',
#  8: 'Public order',
#  9: 'Robbery',
#  10: 'Shoplifting',
#  11: 'Theft from the person',
#  12: 'Vehicle crime',
#  13: 'Violence and sexual offences'}

# %%
#plot of locations of the crimes, colour coded by crime category
plt.scatter(df_crime['Longitude'], df_crime['Latitude'], c=df_crime['Category encoded'],  s=6,  alpha=0.25)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# # Let's look at ward

# %%
#describe the category column
df_crime['Ward Name'].describe()
# Out:
# count                        285107
# unique                           18
# top       Holborn and Covent Garden
# freq                          40616
# Name: Ward Name, dtype: object

# %%
#get all the unique Wards and the 'size' i.e. number of Wards
C = len(df_crime['Ward Name'].unique())
C, df_crime['Ward Name'].unique()
# Out:
# (18,
#  array(['St Pancras and Somers Town', 'Swiss Cottage', "King's Cross",
#         'Highgate', 'Camden Town with Primrose Hill', 'Haverstock',
#         'Frognal and Fitzjohns', 'Belsize', 'Bloomsbury', 'Cantelowes',
#         'Kilburn', 'Kentish Town', 'West Hampstead', 'Fortune Green',
#         'Holborn and Covent Garden', "Regent's Park", 'Gospel Oak',
#         'Hampstead Town'], dtype=object))

# %%
#create another category called 'ward encoded' which contains the encoded ward names,
df_crime['Ward encoded'] = df_crime['Ward Name'].astype('category')
df_crime['Ward encoded'] = df_crime['Ward encoded'].cat.codes
df_crime.dtypes, df_crime
# Out:
# (Category             object
#  Street ID             int64
#  Street Name          object
#  Outcome Category     object
#  Outcome Date         object
#  Service              object
#  Location Subtype     object
#  ID                    int64
#  Persistent ID        object
#  Epoch                object
#  Ward Code            object
#  Ward Name            object
#  Easting             float64
#  Northing            float64
#  Longitude           float64
#  Latitude            float64
#  Last Uploaded        object
#  count                 int64
#  Category encoded       int8
#  Ward encoded           int8
#  dtype: object,
#                              Category  Street ID  \
#  0                        Other theft    1489515
#  1              Anti-social behaviour     960522
#  2              Theft from the person     965233
#  3              Anti-social behaviour     960974
#  4                              Drugs     972275
#  ...                              ...        ...
#  285102         Theft from the person     960590
#  285103                 Bicycle theft     965106
#  285104         Theft from the person     956623
#  285105  Violence and sexual offences    1490576
#  285106         Anti-social behaviour     967753
#
#                                             Street Name  \
#  0                                Kings Cross (station)
#  1                           On or near Wellesley Place
#  2                               On or near Avenue Road
#  3                         On or near Birkenhead Street
#  4                          On or near Oakeshott Avenue
#  ...                                                ...
#  285102  On or near Further/higher Educational Building
#  285103                       On or near Crogsland Road
#  285104                    On or near New Oxford Street
#  285105                          Stockwell (lu Station)
#  285106                      On or near Holly Bush Vale
#
#                                       Outcome Category            Outcome Date  \
#  0                           Status update unavailable  08/01/2017 12:00:00 AM
#  1                                                 NaN                     NaN
#  2       Investigation complete; no suspect identified  08/01/2015 12:00:00 AM
#  3                                                 NaN                     NaN
#  4           Offender given a drugs possession warning  06/01/2015 12:00:00 AM
#  ...                                               ...                     ...
#  285102  Investigation complete; no suspect identified  02/01/2021 12:00:00 AM
#  285103  Investigation complete; no suspect identified  07/01/2020 12:00:00 AM
#  285104  Investigation complete; no suspect identified  08/01/2020 12:00:00 AM
#  285105                            Under investigation  04/01/2021 12:00:00 AM
#  285106                                            NaN                     NaN
#
#                           Service            Location Subtype        ID  \
#  0       British Transport Police                     Station  64777250
#  1                   Police Force                         NaN  51520755
#  2                   Police Force                         NaN  42356413
#  3                   Police Force                         NaN  59431385
#  4                   Police Force                         NaN  41931981
#  ...                          ...                         ...       ...
#  285102              Police Force                         NaN  89122019
#  285103              Police Force                         NaN  85535188
#  285104              Police Force                         NaN  86477977
#  285105  British Transport Police  London Underground Station  92235600
#  285106              Police Force                         NaN  91436630
#
#                                              Persistent ID  \
#  0                                                     NaN
#  1                                                     NaN
#  2       915131bf174019fd2fcf5aa4af305f7b2b34a763d8fcb0...
#  3                                                     NaN
#  4       bd5bef6ee7b3711e69ecfc40c1c256d45336f23aeda337...
#  ...                                                   ...
#  285102  4a3a5bf8ad595c876ffe511f324ac6747f73e919899936...
#  285103  713fa4406dc2cc7d7a358a6850e83d26231b1c4f0d7cc4...
#  285104  69fbc9f7c0879fbd1b6a6e9da575080d20761a2e582671...
#  285105                                                NaN
#  285106                                                NaN
#
#                           Epoch  Ward Code                   Ward Name  \
#  0       04/01/2017 12:00:00 AM  E05000143  St Pancras and Somers Town
#  1       09/01/2016 12:00:00 AM  E05000143  St Pancras and Somers Town
#  2       07/01/2015 12:00:00 AM  E05000144               Swiss Cottage
#  3       08/01/2017 12:00:00 AM  E05000141                King's Cross
#  4       06/01/2015 12:00:00 AM  E05000137                    Highgate
#  ...                        ...        ...                         ...
#  285102  12/01/2020 12:00:00 AM  E05000129                  Bloomsbury
#  285103  07/01/2020 12:00:00 AM  E05000136                  Haverstock
#  285104  08/01/2020 12:00:00 AM  E05000129                  Bloomsbury
#  285105  04/01/2021 12:00:00 AM  E05000138   Holborn and Covent Garden
#  285106  03/01/2021 12:00:00 AM  E05000133       Frognal and Fitzjohns
#
#            Easting   Northing  Longitude   Latitude Last Uploaded  count  \
#  0       530277.37  183101.39  -0.123189  51.531800    11/07/2018      1
#  1       529707.23  182682.77  -0.131558  51.528169    11/07/2018      1
#  2       526716.88  184227.86  -0.174124  51.542741    05/05/2016      1
#  3       530390.22  182860.71  -0.121652  51.529611    03/11/2017      1
#  4       528335.87  186805.94  -0.149851  51.565544    21/08/2015      1
#  ...           ...        ...        ...        ...           ...    ...
#  285102  529587.23  182301.71  -0.133427  51.524772    11/06/2021      1
#  285103  528245.25  184505.68  -0.151958  51.544885    11/06/2021      1
#  285104  529978.23  181417.72  -0.128120  51.516738    11/06/2021      1
#  285105  530354.22  181743.26  -0.122584  51.519577    11/06/2021      1
#  285106  526340.28  185750.68  -0.178968  51.556503    11/06/2021      1
#
#          Category encoded  Ward encoded
#  0                      6            15
#  1                      0            15
#  2                     11            16
#  3                      0            13
#  4                      4             9
#  ...                  ...           ...
#  285102                11             1
#  285103                 1             8
#  285104                11             1
#  285105                13            10
#  285106                 0             5
#
#  [285107 rows x 20 columns])

# %%
#plot of locations of the crimes, colour coded by crime category
plt.scatter(df_crime['Longitude'],df_crime['Latitude'], c=df_crime['Ward encoded'], s=6,  alpha=0.25)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
total_crimes_byward = df_crime.groupby(['Ward Name']).sum()      #sum 'count' number of crimes by date
total_crimes_byward.drop(['Street ID', 'Easting', 'Ward encoded','Northing', 'Category encoded', 'Longitude', 'Latitude', 'ID'], axis=1, inplace=True)     #remove all other columns
total_crimes_byward['Ward name'] = total_crimes_byward.index
total_crimes_byward
# Out:
#                                 count                       Ward name
# Ward Name
# Belsize                          8108                         Belsize
# Bloomsbury                      36759                      Bloomsbury
# Camden Town with Primrose Hill  30958  Camden Town with Primrose Hill
# Cantelowes                       9895                      Cantelowes
# Fortune Green                    7758                   Fortune Green
# Frognal and Fitzjohns            6239           Frognal and Fitzjohns
# Gospel Oak                       7725                      Gospel Oak
# Hampstead Town                   8297                  Hampstead Town
# Haverstock                      10225                      Haverstock
# Highgate                         7952                        Highgate
# Holborn and Covent Garden       40616       Holborn and Covent Garden
# Kentish Town                    13230                    Kentish Town
# Kilburn                         12637                         Kilburn
# King's Cross                    19246                    King's Cross
# Regent's Park                   23510                   Regent's Park
# St Pancras and Somers Town      24313      St Pancras and Somers Town
# Swiss Cottage                    8207                   Swiss Cottage
# West Hampstead                   9432                  West Hampstead

# %%
# export the 'cleaned' df_crime dataframe as a csv file 
total_crimes_byward.to_csv('total_crimes_byward.csv', index=False)

# %%
#plot of crime numbers by ward
plt.bar(total_crimes_byward['Ward name'],total_crimes_byward['count']) 
plt.xlabel('Ward name')
plt.xticks(rotation=90)
plt.ylabel('crime count')
# Out:
# Text(0, 0.5, 'crime count')

# %% [markdown]
# #Let's look at street name

# %%
#describe the category column
df_crime['Street Name'].describe()
# Out:
# count                     285107
# unique                      1208
# top       On or near Supermarket
# freq                       10377
# Name: Street Name, dtype: object

# %%
#get all the street names and the 'size' i.e. number of unique streets
C = len(df_crime['Street Name'].unique())
C, df_crime['Street Name'].unique()
# Out:
# (1208,
#  array(['Kings Cross (station)', 'On or near Wellesley Place',
#         'On or near Avenue Road', ..., 'Stockwell (lu Station)',
#         'South Hampstead (station)', 'Maidenhead (station)'], dtype=object))

# %%
total_crimes_bystreet = df_crime.groupby(['Street Name']).sum()      #sum 'count' number of crimes by date
total_crimes_bystreet.drop([ 'Easting', 'Northing', 'Ward encoded', 'Category encoded', 'Longitude', 'Latitude', 'ID', 'Street ID'], axis=1, inplace=True)     #remove all other columns
total_crimes_bystreet['Street'] = total_crimes_bystreet.index        #create another column for the street ID, called Street
total_crimes_bystreet.sort_values(by = 'count')
# Out:
#                                                 count  \
# Street Name
# On or near Bloomsbury Square                        1
# South Hampstead                                     1
# On or near Powis Place                              2
# On or near Birchwood Drive                          3
# On or near Osnaburgh Terrace                        3
# ...                                               ...
# On or near Further/higher Educational Building   5399
# On or near Parking Area                          6825
# On or near Theatre/concert Hall                  7795
# On or near Nightclub                             9452
# On or near Supermarket                          10377
#
#                                                                                         Street
# Street Name
# On or near Bloomsbury Square                                      On or near Bloomsbury Square
# South Hampstead                                                                South Hampstead
# On or near Powis Place                                                  On or near Powis Place
# On or near Birchwood Drive                                          On or near Birchwood Drive
# On or near Osnaburgh Terrace                                      On or near Osnaburgh Terrace
# ...                                                                                        ...
# On or near Further/higher Educational Building  On or near Further/higher Educational Building
# On or near Parking Area                                                On or near Parking Area
# On or near Theatre/concert Hall                                On or near Theatre/concert Hall
# On or near Nightclub                                                      On or near Nightclub
# On or near Supermarket                                                  On or near Supermarket
#
# [1208 rows x 2 columns]

# %%
#collect street names where more than 1000 crimes have been committed over the 7 year period
total_crimes_bystreet_important = total_crimes_bystreet[(total_crimes_bystreet['count'] > 1000)]
total_crimes_bystreet_important
# Out:
#                                                 count  \
# Street Name
# Euston (lu Station)                              1210
# Euston (station)                                 1653
# Kings Cross (station)                            1915
# On or near Adelaide Road                         1016
# On or near Camden High Street                    3134
# On or near Conference/exhibition Centre          2325
# On or near Further/higher Educational Building   5399
# On or near Goodge Street                         1041
# On or near Goods Way                             1066
# On or near Granary Street                        1132
# On or near Gray's Inn Road                       1776
# On or near Great Russell Street                  1553
# On or near Hospital                              2873
# On or near Judd Street                           1423
# On or near Kingsgate Place                       1022
# On or near New Oxford Street                     1156
# On or near Nightclub                             9452
# On or near Parking Area                          6825
# On or near Pedestrian Subway                     4052
# On or near Percy Street                          1115
# On or near Petrol Station                        3122
# On or near Police Station                        1385
# On or near Russell Square                        1057
# On or near Shopping Area                         5255
# On or near St Chad's Street                      1161
# On or near Supermarket                          10377
# On or near Theatre/concert Hall                  7795
# On or near West End Lane                         1123
# St Pancras International (station)               3286
#
#                                                                                         Street
# Street Name
# Euston (lu Station)                                                        Euston (lu Station)
# Euston (station)                                                              Euston (station)
# Kings Cross (station)                                                    Kings Cross (station)
# On or near Adelaide Road                                              On or near Adelaide Road
# On or near Camden High Street                                    On or near Camden High Street
# On or near Conference/exhibition Centre                On or near Conference/exhibition Centre
# On or near Further/higher Educational Building  On or near Further/higher Educational Building
# On or near Goodge Street                                              On or near Goodge Street
# On or near Goods Way                                                      On or near Goods Way
# On or near Granary Street                                            On or near Granary Street
# On or near Gray's Inn Road                                          On or near Gray's Inn Road
# On or near Great Russell Street                                On or near Great Russell Street
# On or near Hospital                                                        On or near Hospital
# On or near Judd Street                                                  On or near Judd Street
# On or near Kingsgate Place                                          On or near Kingsgate Place
# On or near New Oxford Street                                      On or near New Oxford Street
# On or near Nightclub                                                      On or near Nightclub
# On or near Parking Area                                                On or near Parking Area
# On or near Pedestrian Subway                                      On or near Pedestrian Subway
# On or near Percy Street                                                On or near Percy Street
# On or near Petrol Station                                            On or near Petrol Station
# On or near Police Station                                            On or near Police Station
# On or near Russell Square                                            On or near Russell Square
# On or near Shopping Area                                              On or near Shopping Area
# On or near St Chad's Street                                        On or near St Chad's Street
# On or near Supermarket                                                  On or near Supermarket
# On or near Theatre/concert Hall                                On or near Theatre/concert Hall
# On or near West End Lane                                              On or near West End Lane
# St Pancras International (station)                          St Pancras International (station)

# %%
#plot street name locations of the crimes against frequency for frequencies greater than 1000
plt.figure(figsize=(20,5))
plt.bar(total_crimes_bystreet_important['Street'],total_crimes_bystreet_important['count']) #, c=df_crime['Ward encoded'], s=6,  alpha=0.25)
plt.xlabel('street')
plt.xticks(rotation=90)
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
# See what sorts of crimes are being committed 'on or near Supermarkets'
df_supermarket = df_crime[df_crime['Street Name'] == 'On or near Supermarket']
df_supermarket_cat = df_supermarket.groupby(['Category encoded']).sum()
df_supermarket_cat['Category'] = ['Anti-social behaviour', 'Bicycle theft', 'Burglary', 'Criminal damage and arson', 'Drugs', 'Other crime',
                                  'Other theft', 'Possession of weapons', 'Public order', 'Robbery', 'Shoplifting', 'Theft from the person',
                                  'Vehicle crime', 'Violence and sexual offences']
#df_supermarket_cat.drop(['Street ID',	'ID',	'Easting',	'Northing',	'Longitude',	'Latitude',	'Ward encoded', 'Street ID encoded', 'Street name encoded'], axis=1, inplace=True)

# %%
df_supermarket
# Out:
#                             Category  Street ID             Street Name  \
# 14      Violence and sexual offences     967943  On or near Supermarket
# 83                             Drugs     964903  On or near Supermarket
# 153                     Public order     961057  On or near Supermarket
# 173                      Shoplifting     956642  On or near Supermarket
# 190                      Other theft     961057  On or near Supermarket
# ...                              ...        ...                     ...
# 284876                   Shoplifting     960761  On or near Supermarket
# 284988                   Other theft     960761  On or near Supermarket
# 285017         Theft from the person     956642  On or near Supermarket
# 285037                   Shoplifting     964904  On or near Supermarket
# 285100         Theft from the person     961057  On or near Supermarket
#
#                                      Outcome Category            Outcome Date  \
# 14                                Under investigation  03/01/2017 12:00:00 AM
# 83                             Awaiting court outcome  01/01/2017 12:00:00 AM
# 153                               Under investigation  07/01/2017 12:00:00 AM
# 173                          Offender given a caution  05/01/2016 12:00:00 AM
# 190                               Under investigation  02/01/2018 12:00:00 AM
# ...                                               ...                     ...
# 284876  Investigation complete; no suspect identified  04/01/2020 12:00:00 AM
# 284988                      Status update unavailable  02/01/2020 12:00:00 AM
# 285017  Investigation complete; no suspect identified  03/01/2020 12:00:00 AM
# 285037                            Under investigation  02/01/2021 12:00:00 AM
# 285100  Investigation complete; no suspect identified  03/01/2020 12:00:00 AM
#
#              Service Location Subtype        ID  \
# 14      Police Force              NaN  55580264
# 83      Police Force              NaN  54103655
# 153     Police Force              NaN  59006709
# 173     Police Force              NaN  48875086
# 190     Police Force              NaN  63301064
# ...              ...              ...       ...
# 284876  Police Force              NaN  82521901
# 284988  Police Force              NaN  78759482
# 285017  Police Force              NaN  81117877
# 285037  Police Force              NaN  90744076
# 285100  Police Force              NaN  77729402
#
#                                             Persistent ID  \
# 14      adef0ec085796c97a9dbca411af4b41adc33838025e704...
# 83      8d1dd1f1d8a5db395fe6605a9b0872313c4c0147e90e36...
# 153     3f89913cf13f10568b6902b7cff9bc6803a97bc8406b61...
# 173     d94c8476588645b2e12c7a4d4f150d0dfb3642f0500d6e...
# 190     3baec9b674177b48b22ab949f54905fb58f9e8ce65cd3c...
# ...                                                   ...
# 284876  c5e7994cd7ffc777d68f2d14eed7fd0567e46dcf4cd3be...
# 284988  1c4127e0f43a8f921941be017d339cca93baa730709ed0...
# 285017  c7805347ee7661e6ddb06a619daf577e06dff8d8060c46...
# 285037  b9186cbff333affc3ef2f2fb7400912d12141c3bd1f1d8...
# 285100  0530a3b53917138ef0d094c4e3c807868c2d4a2c3855f4...
#
#                          Epoch  Ward Code                       Ward Name  \
# 14      03/01/2017 12:00:00 AM  E05000128                         Belsize
# 83      01/01/2017 12:00:00 AM  E05000130  Camden Town with Primrose Hill
# 153     07/01/2017 12:00:00 AM  E05000138       Holborn and Covent Garden
# 173     05/01/2016 12:00:00 AM  E05000129                      Bloomsbury
# 190     02/01/2018 12:00:00 AM  E05000138       Holborn and Covent Garden
# ...                        ...        ...                             ...
# 284876  03/01/2020 12:00:00 AM  E05000129                      Bloomsbury
# 284988  10/01/2019 12:00:00 AM  E05000129                      Bloomsbury
# 285017  02/01/2020 12:00:00 AM  E05000129                      Bloomsbury
# 285037  02/01/2021 12:00:00 AM  E05000130  Camden Town with Primrose Hill
# 285100  09/01/2019 12:00:00 AM  E05000138       Holborn and Covent Garden
#
#           Easting   Northing  Longitude   Latitude Last Uploaded  count  \
# 14      527508.87  184588.86  -0.162579  51.545807    20/06/2017      1
# 83      529032.87  184038.94  -0.140815  51.540519    20/06/2017      1
# 153     530807.22  181631.72  -0.116100  51.518470    03/11/2017      1
# 173     529743.22  181466.80  -0.131487  51.517233    11/07/2018      1
# 190     530807.22  181631.72  -0.116100  51.518470    13/04/2018      1
# ...           ...        ...        ...        ...           ...    ...
# 284876  529527.27  181767.74  -0.134487  51.519987    11/06/2021      1
# 284988  529527.27  181767.74  -0.134487  51.519987    11/06/2021      1
# 285017  529743.22  181466.80  -0.131487  51.517233    11/06/2021      1
# 285037  528956.26  183681.69  -0.142012  51.537318    11/06/2021      1
# 285100  530807.22  181631.72  -0.116100  51.518470    11/06/2021      1
#
#         Category encoded  Ward encoded
# 14                    13             0
# 83                     4             2
# 153                    8            10
# 173                   10             1
# 190                    6            10
# ...                  ...           ...
# 284876                10             1
# 284988                 6             1
# 285017                11             1
# 285037                10             2
# 285100                11            10
#
# [10377 rows x 20 columns]

# %%
df_supermarket_cat
# Out:
#                    Street ID            ID       Easting      Northing  \
# Category encoded
# 0                  604738302   41443280346  3.317188e+08  1.150778e+08
# 1                  275436794   19213198842  1.513047e+08  5.242455e+07
# 2                  366582321   24587728454  2.007663e+08  6.983370e+07
# 3                  246063883   15958362288  1.347781e+08  4.689477e+07
# 4                  212249860   13762762035  1.162796e+08  4.045389e+07
# 5                   62660489    3923904436  3.435655e+07  1.193706e+07
# 6                 2225199535  144685921657  1.223069e+09  4.229264e+08
# 7                   39547554    2883608194  2.167038e+07  7.534254e+06
# 8                  573774185   38424446685  3.145315e+08  1.093295e+08
# 9                  403501907   28428734809  2.215027e+08  7.680353e+07
# 10                1682373954  109516577972  9.219688e+08  3.204530e+08
# 11                1627785044  111032631291  8.957743e+08  3.095265e+08
# 12                 272280034   18039628325  1.489265e+08  5.191389e+07
# 13                1403524568   92240303524  7.696553e+08  2.673616e+08
#
#                    Longitude       Latitude  count  Ward encoded  \
# Category encoded
# 0                 -96.003259   32363.076872    628        5554.0
# 1                 -40.324622   14738.693475    286        2039.0
# 2                 -57.373443   19584.546146    380        2858.0
# 3                 -37.719112   13142.543073    255        1981.0
# 4                 -32.537812   11338.625607    220        1316.0
# 5                  -9.601608    3349.911351     65         367.0
# 6                -327.240712  119138.564090   2312       15729.0
# 7                  -6.064103    2113.063561     41         243.0
# 8                 -87.335895   30665.098459    595        4445.0
# 9                 -61.438800   21592.735696    419        3070.0
# 10               -263.134556   89932.218584   1745       11059.0
# 11               -237.354814   87239.620983   1693       12348.0
# 12                -43.455023   14534.617424    282        1977.0
# 13               -214.094541   75037.740620   1456       10873.0
#
#                                       Category
# Category encoded
# 0                        Anti-social behaviour
# 1                                Bicycle theft
# 2                                     Burglary
# 3                    Criminal damage and arson
# 4                                        Drugs
# 5                                  Other crime
# 6                                  Other theft
# 7                        Possession of weapons
# 8                                 Public order
# 9                                      Robbery
# 10                                 Shoplifting
# 11                       Theft from the person
# 12                               Vehicle crime
# 13                Violence and sexual offences

# %%
plt.bar(df_supermarket_cat['Category'], df_supermarket_cat['count'])
plt.xlabel('Category')
plt.xticks(rotation=90)
plt.ylabel('total no. of crimes')
plt.title('crimes occuring on or near supermarket')
# Out:
# Text(0.5, 1.0, 'crimes occuring on or near supermarket')

# %%
# Get the unique ward names from 'On or near supermarket' crimes
df_supermarket['Ward Name'].unique()
# Out:
# array(['Belsize', 'Camden Town with Primrose Hill',
#        'Holborn and Covent Garden', 'Bloomsbury', 'Kilburn', 'Haverstock',
#        'Kentish Town', 'Swiss Cottage', "Regent's Park",
#        'Frognal and Fitzjohns'], dtype=object)

# %%
# group 'on or near supermarket' crimes by each ward to see which ward has the most number of 'on or near supermarket' crimes
df_supermarket_byward = df_supermarket.groupby(['Ward Name']).sum()
df_supermarket_byward
# Out:
#                                  Street ID            ID       Easting  \
# Ward Name
# Belsize                          746259749   51072743262  4.066053e+08
# Bloomsbury                      1749335729  120802610368  9.666007e+08
# Camden Town with Primrose Hill  1657843984  105832395477  9.084565e+08
# Frognal and Fitzjohns            112261900    7590513585  6.105333e+07
# Haverstock                       621541144   38554862026  3.402537e+08
# Holborn and Covent Garden       1661244058  110352416376  9.201913e+08
# Kentish Town                    1347573119   91351317409  7.363658e+08
# Kilburn                          816733841   54072717407  4.444561e+08
# Regent's Park                    592749432   39507201444  3.265034e+08
# Swiss Cottage                    690175474   45004311504  3.758165e+08
#
#                                     Northing   Longitude      Latitude  count  \
# Ward Name
# Belsize                         1.425490e+08 -126.741549  39743.911681    771
# Bloomsbury                      3.314297e+08 -242.486775  94021.266339   1825
# Camden Town with Primrose Hill  3.160758e+08 -247.993202  88545.771520   1718
# Frognal and Fitzjohns           2.154103e+07  -20.794276   5980.500640    116
# Haverstock                      1.187204e+08  -96.988332  33193.983088    644
# Holborn and Covent Garden       3.148084e+08 -204.676896  89331.816656   1734
# Kentish Town                    2.577095e+08 -196.103463  71758.129799   1392
# Kilburn                         1.554645e+08 -163.946817  43601.884267    846
# Regent's Park                   1.125054e+08  -85.950568  31791.069995    617
# Swiss Cottage                   1.316668e+08 -127.996422  36802.721956    714
#
#                                 Category encoded  Ward encoded
# Ward Name
# Belsize                                   5565.0           0.0
# Bloomsbury                               14770.0        1825.0
# Camden Town with Primrose Hill           14237.0        3436.0
# Frognal and Fitzjohns                     1022.0         580.0
# Haverstock                                6000.0        5152.0
# Holborn and Covent Garden                14466.0       17340.0
# Kentish Town                             12057.0       15312.0
# Kilburn                                   7561.0       10152.0
# Regent's Park                             3714.0        8638.0
# Swiss Cottage                             4699.0       11424.0

# %%
plt.bar(df_supermarket_byward.index, df_supermarket_byward['count'])
plt.xlabel('Ward Name')
plt.xticks(rotation=90)
plt.title('Supermarket crimes in wards in London borough of Camden')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df_supermarket_belsize      = df_supermarket[df_supermarket['Ward Name'] == 'Belsize']
df_supermarket_camden       = df_supermarket[df_supermarket['Ward Name'] == "Camden Town with Primrose Hill"]
df_supermarket_holborn      = df_supermarket[df_supermarket['Ward Name'] == 'Holborn and Covent Garden']
df_supermarket_bloomsbury   = df_supermarket[df_supermarket['Ward Name'] == 'Bloomsbury']
df_supermarket_kilburn      = df_supermarket[df_supermarket['Ward Name'] == "Kilburn"]
df_supermarket_haverstock   = df_supermarket[df_supermarket['Ward Name'] == "Haverstock"]
df_supermarket_kentish      = df_supermarket[df_supermarket['Ward Name'] == 'Kentish Town']
df_supermarket_swiss        = df_supermarket[df_supermarket['Ward Name'] == 'Swiss Cottage']
df_supermarket_regent       = df_supermarket[df_supermarket['Ward Name'] == "Regent's Park"]
df_supermarket_forgnal      = df_supermarket[df_supermarket['Ward Name'] == "Frognal and Fitzjohns"]

# %%
# See what sorts of crimes are being committed 'on or near Nightclub'
df_nightclub = df_crime[df_crime['Street Name'] == 'On or near Nightclub']
df_nightclub_cat = df_nightclub.groupby(['Category encoded']).sum()
df_nightclub_cat['Category'] = ['Anti-social behaviour', 'Bicycle theft', 'Burglary', 'Criminal damage and arson', 'Drugs', 'Other crime',
                                  'Other theft', 'Possession of weapons', 'Public order', 'Robbery', 'Shoplifting', 'Theft from the person',
                                  'Vehicle crime', 'Violence and sexual offences']
#df_nightclub_cat.drop(['Street ID',	'ID',	'Easting',	'Northing',	'Longitude',	'Latitude',	'Ward encoded', 'Street ID encoded', 'Street name encoded'], axis=1, inplace=True)

# %%
df_nightclub['Ward Name'].unique()
# Out:
# array(['Camden Town with Primrose Hill', 'West Hampstead',
#        'Holborn and Covent Garden', 'Haverstock', "Regent's Park",
#        'Bloomsbury'], dtype=object)

# %%
df_nightclub_byward = df_nightclub.groupby(['Ward Name']).sum()
df_nightclub_byward
# Out:
#                                  Street ID            ID       Easting  \
# Ward Name
# Bloomsbury                       382333432   25459519494  2.106767e+08
# Camden Town with Primrose Hill  4922494599  319152176122  2.697496e+09
# Haverstock                       282781332   17417600117  1.548312e+08
# Holborn and Covent Garden       1498656134  100455118931  8.291958e+08
# Regent's Park                    228681774   14656197466  1.253749e+08
# West Hampstead                  1800901917  123459670745  9.787799e+08
#
#                                     Northing   Longitude       Latitude  \
# Ward Name
# Bloomsbury                      7.247019e+07  -54.565658   20506.110896
# Camden Town with Primrose Hill  9.387603e+08 -734.021859  262908.208279
# Haverstock                      5.400383e+07  -43.750467   15102.133281
# Holborn and Covent Garden       2.836388e+08 -180.310075   80471.207848
# Regent's Park                   4.352636e+07  -33.485019   12214.286301
# West Hampstead                  3.439778e+08 -344.341675   95931.504251
#
#                                 count  Category encoded  Ward encoded
# Ward Name
# Bloomsbury                        398            2862.0         398.0
# Camden Town with Primrose Hill   5101           40165.0       10202.0
# Haverstock                        293            2634.0        2344.0
# Holborn and Covent Garden        1562           11495.0       15620.0
# Regent's Park                     237            1896.0        3318.0
# West Hampstead                   1861           12866.0       31637.0

# %%
plt.bar(df_nightclub_byward.index, df_nightclub_byward['count'])
plt.xlabel('Ward Name')
plt.xticks(rotation=90)
plt.title('Nightclub crimes in wards in London borough of Camden')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df_nightclub_cat
# Out:
#                    Street ID            ID       Easting      Northing  \
# Category encoded
# 0                  946693874   65224811293  5.183282e+08  1.803105e+08
# 1                  147458649   10080094128  8.091677e+07  2.805970e+07
# 2                  379893332   25934413739  2.080527e+08  7.236287e+07
# 3                  228664594   14710343895  1.252033e+08  4.357870e+07
# 4                  700578175   43368315750  3.838443e+08  1.336050e+08
# 5                   40540762    2498675435  2.217682e+07  7.728461e+06
# 6                 1833064532  119421953660  1.005743e+09  3.489474e+08
# 7                   31840430    2190615707  1.744344e+07  6.071214e+06
# 8                  438980626   29067683064  2.404218e+08  8.366515e+07
# 9                  353970162   23899555605  1.940221e+08  6.742434e+07
# 10                 608921104   41090742627  3.333203e+08  1.159667e+08
# 11                1653461214  109266330484  9.072287e+08  3.148077e+08
# 12                 209284304   13935665601  1.145211e+08  3.988548e+07
# 13                1542497430   99911081887  8.451330e+08  2.939641e+08
#
#                    Longitude      Latitude  count  Ward encoded  \
# Category encoded
# 0                -147.612134  50559.307392    981        8001.0
# 1                 -21.941033   7884.820818    153        1145.0
# 2                 -61.092895  20305.714258    394        4020.0
# 3                 -35.940207  12214.795358    237        1926.0
# 4                -105.584425  37418.400646    726        2150.0
# 5                  -6.526959   2164.700576     42         345.0
# 6                -275.074756  98020.323541   1902       13588.0
# 7                  -4.857713   1700.821626     33         130.0
# 8                 -68.239039  23450.346032    455        3162.0
# 9                 -53.628899  18914.337812    367        2227.0
# 10                -96.097446  32520.720978    631        5915.0
# 11               -242.655250  88384.630481   1715        8459.0
# 12                -34.592543  11183.895991    217        2647.0
# 13               -236.631454  82410.635347   1599        9804.0
#
#                                       Category
# Category encoded
# 0                        Anti-social behaviour
# 1                                Bicycle theft
# 2                                     Burglary
# 3                    Criminal damage and arson
# 4                                        Drugs
# 5                                  Other crime
# 6                                  Other theft
# 7                        Possession of weapons
# 8                                 Public order
# 9                                      Robbery
# 10                                 Shoplifting
# 11                       Theft from the person
# 12                               Vehicle crime
# 13                Violence and sexual offences

# %%
plt.bar(df_nightclub_cat['Category'], df_nightclub_cat['count'])
plt.xlabel('Category')
plt.xticks(rotation=90)
plt.ylabel('total no. of crimes')
plt.title('crimes occuring on or near Nightclub')
# Out:
# Text(0.5, 1.0, 'crimes occuring on or near Nightclub')

# %% [markdown]
# #Let's encode street names and street IDs

# %%
#create another category called 'ward encoded' which contains the encoded ward names,
df_crime
# Out:
#                             Category  Street ID  \
# 0                        Other theft    1489515
# 1              Anti-social behaviour     960522
# 2              Theft from the person     965233
# 3              Anti-social behaviour     960974
# 4                              Drugs     972275
# ...                              ...        ...
# 285102         Theft from the person     960590
# 285103                 Bicycle theft     965106
# 285104         Theft from the person     956623
# 285105  Violence and sexual offences    1490576
# 285106         Anti-social behaviour     967753
#
#                                            Street Name  \
# 0                                Kings Cross (station)
# 1                           On or near Wellesley Place
# 2                               On or near Avenue Road
# 3                         On or near Birkenhead Street
# 4                          On or near Oakeshott Avenue
# ...                                                ...
# 285102  On or near Further/higher Educational Building
# 285103                       On or near Crogsland Road
# 285104                    On or near New Oxford Street
# 285105                          Stockwell (lu Station)
# 285106                      On or near Holly Bush Vale
#
#                                      Outcome Category            Outcome Date  \
# 0                           Status update unavailable  08/01/2017 12:00:00 AM
# 1                                                 NaN                     NaN
# 2       Investigation complete; no suspect identified  08/01/2015 12:00:00 AM
# 3                                                 NaN                     NaN
# 4           Offender given a drugs possession warning  06/01/2015 12:00:00 AM
# ...                                               ...                     ...
# 285102  Investigation complete; no suspect identified  02/01/2021 12:00:00 AM
# 285103  Investigation complete; no suspect identified  07/01/2020 12:00:00 AM
# 285104  Investigation complete; no suspect identified  08/01/2020 12:00:00 AM
# 285105                            Under investigation  04/01/2021 12:00:00 AM
# 285106                                            NaN                     NaN
#
#                          Service            Location Subtype        ID  \
# 0       British Transport Police                     Station  64777250
# 1                   Police Force                         NaN  51520755
# 2                   Police Force                         NaN  42356413
# 3                   Police Force                         NaN  59431385
# 4                   Police Force                         NaN  41931981
# ...                          ...                         ...       ...
# 285102              Police Force                         NaN  89122019
# 285103              Police Force                         NaN  85535188
# 285104              Police Force                         NaN  86477977
# 285105  British Transport Police  London Underground Station  92235600
# 285106              Police Force                         NaN  91436630
#
#                                             Persistent ID  \
# 0                                                     NaN
# 1                                                     NaN
# 2       915131bf174019fd2fcf5aa4af305f7b2b34a763d8fcb0...
# 3                                                     NaN
# 4       bd5bef6ee7b3711e69ecfc40c1c256d45336f23aeda337...
# ...                                                   ...
# 285102  4a3a5bf8ad595c876ffe511f324ac6747f73e919899936...
# 285103  713fa4406dc2cc7d7a358a6850e83d26231b1c4f0d7cc4...
# 285104  69fbc9f7c0879fbd1b6a6e9da575080d20761a2e582671...
# 285105                                                NaN
# 285106                                                NaN
#
#                          Epoch  Ward Code                   Ward Name  \
# 0       04/01/2017 12:00:00 AM  E05000143  St Pancras and Somers Town
# 1       09/01/2016 12:00:00 AM  E05000143  St Pancras and Somers Town
# 2       07/01/2015 12:00:00 AM  E05000144               Swiss Cottage
# 3       08/01/2017 12:00:00 AM  E05000141                King's Cross
# 4       06/01/2015 12:00:00 AM  E05000137                    Highgate
# ...                        ...        ...                         ...
# 285102  12/01/2020 12:00:00 AM  E05000129                  Bloomsbury
# 285103  07/01/2020 12:00:00 AM  E05000136                  Haverstock
# 285104  08/01/2020 12:00:00 AM  E05000129                  Bloomsbury
# 285105  04/01/2021 12:00:00 AM  E05000138   Holborn and Covent Garden
# 285106  03/01/2021 12:00:00 AM  E05000133       Frognal and Fitzjohns
#
#           Easting   Northing  Longitude   Latitude Last Uploaded  count  \
# 0       530277.37  183101.39  -0.123189  51.531800    11/07/2018      1
# 1       529707.23  182682.77  -0.131558  51.528169    11/07/2018      1
# 2       526716.88  184227.86  -0.174124  51.542741    05/05/2016      1
# 3       530390.22  182860.71  -0.121652  51.529611    03/11/2017      1
# 4       528335.87  186805.94  -0.149851  51.565544    21/08/2015      1
# ...           ...        ...        ...        ...           ...    ...
# 285102  529587.23  182301.71  -0.133427  51.524772    11/06/2021      1
# 285103  528245.25  184505.68  -0.151958  51.544885    11/06/2021      1
# 285104  529978.23  181417.72  -0.128120  51.516738    11/06/2021      1
# 285105  530354.22  181743.26  -0.122584  51.519577    11/06/2021      1
# 285106  526340.28  185750.68  -0.178968  51.556503    11/06/2021      1
#
#         Category encoded  Ward encoded
# 0                      6            15
# 1                      0            15
# 2                     11            16
# 3                      0            13
# 4                      4             9
# ...                  ...           ...
# 285102                11             1
# 285103                 1             8
# 285104                11             1
# 285105                13            10
# 285106                 0             5
#
# [285107 rows x 20 columns]

# %%
#create another category called 'ward encoded' which contains the encoded ward names,
df_crime['Street ID encoded'] = df_crime['Street ID'].astype('category')
df_crime['Street ID encoded'] = df_crime['Street ID encoded'].cat.codes
df_crime.sort_values(by = 'Street ID')
# Out:
#                             Category  Street ID               Street Name  \
# 157062         Anti-social behaviour     587590            On or near A40
# 63586          Anti-social behaviour     587590            On or near A40
# 19936          Anti-social behaviour     587590            On or near A40
# 88600          Anti-social behaviour     587590            On or near A40
# 198482         Anti-social behaviour     587590            On or near A40
# ...                              ...        ...                       ...
# 269338                   Other theft    1490647  West Hampstead (station)
# 251244                  Public order    1490652      Maidenhead (station)
# 272710  Violence and sexual offences    1490652      Maidenhead (station)
# 224075  Violence and sexual offences    1490652      Maidenhead (station)
# 228285  Violence and sexual offences    1490652      Maidenhead (station)
#
#                  Outcome Category            Outcome Date  \
# 157062                        NaN                     NaN
# 63586                         NaN                     NaN
# 19936                         NaN                     NaN
# 88600                         NaN                     NaN
# 198482                        NaN                     NaN
# ...                           ...                     ...
# 269338  Status update unavailable  07/01/2020 12:00:00 AM
# 251244        Under investigation  04/01/2021 12:00:00 AM
# 272710        Under investigation  04/01/2021 12:00:00 AM
# 224075        Under investigation  04/01/2021 12:00:00 AM
# 228285        Under investigation  02/01/2021 12:00:00 AM
#
#                          Service Location Subtype        ID  \
# 157062              Police Force              NaN  49559541
# 63586               Police Force              NaN  69563065
# 19936               Police Force              NaN  77026560
# 88600               Police Force              NaN  72326178
# 198482              Police Force              NaN  55498098
# ...                          ...              ...       ...
# 269338  British Transport Police          Station  89399285
# 251244  British Transport Police          Station  92237204
# 272710  British Transport Police          Station  92237202
# 224075  British Transport Police          Station  92237203
# 228285  British Transport Police          Station  90805354
#
#                                             Persistent ID  \
# 157062                                                NaN
# 63586                                                 NaN
# 19936                                                 NaN
# 88600   0696d5cba9eaef5fac2506a55c5e974fd786bfb63e2543...
# 198482  a53e658c6e6d72a3c1d6f7ec86eb629f09e9aa4c714713...
# ...                                                   ...
# 269338                                                NaN
# 251244                                                NaN
# 272710                                                NaN
# 224075                                                NaN
# 228285                                                NaN
#
#                          Epoch  ...                       Ward Name  \
# 157062  06/01/2016 12:00:00 AM  ...       Holborn and Covent Garden
# 63586   10/01/2018 12:00:00 AM  ...       Holborn and Covent Garden
# 19936   08/01/2019 12:00:00 AM  ...       Holborn and Covent Garden
# 88600   02/01/2019 12:00:00 AM  ...       Holborn and Covent Garden
# 198482  08/01/2016 12:00:00 AM  ...       Holborn and Covent Garden
# ...                        ...  ...                             ...
# 269338  03/01/2020 12:00:00 AM  ...                  West Hampstead
# 251244  04/01/2021 12:00:00 AM  ...  Camden Town with Primrose Hill
# 272710  04/01/2021 12:00:00 AM  ...  Camden Town with Primrose Hill
# 224075  04/01/2021 12:00:00 AM  ...  Camden Town with Primrose Hill
# 228285  02/01/2021 12:00:00 AM  ...  Camden Town with Primrose Hill
#
#           Easting   Northing  Longitude   Latitude  Last Uploaded count  \
# 157062  531398.25  181576.75  -0.107607  51.517839     11/07/2018     1
# 63586   531398.25  181576.75  -0.107607  51.517839     16/01/2019     1
# 19936   531398.25  181576.75  -0.107607  51.517839     28/10/2019     1
# 88600   531398.25  181576.75  -0.107607  51.517839     28/10/2019     1
# 198482  531398.25  181576.75  -0.107607  51.517839     11/07/2018     1
# ...           ...        ...        ...        ...            ...   ...
# 269338  525526.26  184731.82  -0.191067  51.547528     11/06/2021     1
# 251244  529100.23  184075.69  -0.139793  51.540826     11/06/2021     1
# 272710  529100.23  184075.69  -0.139793  51.540826     11/06/2021     1
# 224075  529100.23  184075.69  -0.139793  51.540826     11/06/2021     1
# 228285  529100.23  184075.69  -0.139793  51.540826     11/06/2021     1
#
#         Category encoded  Ward encoded  Street ID encoded
# 157062                 0            10                  0
# 63586                  0            10                  0
# 19936                  0            10                  0
# 88600                  0            10                  0
# 198482                 0            10                  0
# ...                  ...           ...                ...
# 269338                 6            17               1541
# 251244                 8             2               1542
# 272710                13             2               1542
# 224075                13             2               1542
# 228285                13             2               1542
#
# [285107 rows x 21 columns]

# %%
#encode street names
df_crime['Street name encoded'] = df_crime['Street Name'].astype('category')
df_crime['Street name encoded'] = df_crime['Street name encoded'].cat.codes
df_crime
# Out:
#                             Category  Street ID  \
# 0                        Other theft    1489515
# 1              Anti-social behaviour     960522
# 2              Theft from the person     965233
# 3              Anti-social behaviour     960974
# 4                              Drugs     972275
# ...                              ...        ...
# 285102         Theft from the person     960590
# 285103                 Bicycle theft     965106
# 285104         Theft from the person     956623
# 285105  Violence and sexual offences    1490576
# 285106         Anti-social behaviour     967753
#
#                                            Street Name  \
# 0                                Kings Cross (station)
# 1                           On or near Wellesley Place
# 2                               On or near Avenue Road
# 3                         On or near Birkenhead Street
# 4                          On or near Oakeshott Avenue
# ...                                                ...
# 285102  On or near Further/higher Educational Building
# 285103                       On or near Crogsland Road
# 285104                    On or near New Oxford Street
# 285105                          Stockwell (lu Station)
# 285106                      On or near Holly Bush Vale
#
#                                      Outcome Category            Outcome Date  \
# 0                           Status update unavailable  08/01/2017 12:00:00 AM
# 1                                                 NaN                     NaN
# 2       Investigation complete; no suspect identified  08/01/2015 12:00:00 AM
# 3                                                 NaN                     NaN
# 4           Offender given a drugs possession warning  06/01/2015 12:00:00 AM
# ...                                               ...                     ...
# 285102  Investigation complete; no suspect identified  02/01/2021 12:00:00 AM
# 285103  Investigation complete; no suspect identified  07/01/2020 12:00:00 AM
# 285104  Investigation complete; no suspect identified  08/01/2020 12:00:00 AM
# 285105                            Under investigation  04/01/2021 12:00:00 AM
# 285106                                            NaN                     NaN
#
#                          Service            Location Subtype        ID  \
# 0       British Transport Police                     Station  64777250
# 1                   Police Force                         NaN  51520755
# 2                   Police Force                         NaN  42356413
# 3                   Police Force                         NaN  59431385
# 4                   Police Force                         NaN  41931981
# ...                          ...                         ...       ...
# 285102              Police Force                         NaN  89122019
# 285103              Police Force                         NaN  85535188
# 285104              Police Force                         NaN  86477977
# 285105  British Transport Police  London Underground Station  92235600
# 285106              Police Force                         NaN  91436630
#
#                                             Persistent ID  \
# 0                                                     NaN
# 1                                                     NaN
# 2       915131bf174019fd2fcf5aa4af305f7b2b34a763d8fcb0...
# 3                                                     NaN
# 4       bd5bef6ee7b3711e69ecfc40c1c256d45336f23aeda337...
# ...                                                   ...
# 285102  4a3a5bf8ad595c876ffe511f324ac6747f73e919899936...
# 285103  713fa4406dc2cc7d7a358a6850e83d26231b1c4f0d7cc4...
# 285104  69fbc9f7c0879fbd1b6a6e9da575080d20761a2e582671...
# 285105                                                NaN
# 285106                                                NaN
#
#                          Epoch  ...    Easting   Northing  Longitude  \
# 0       04/01/2017 12:00:00 AM  ...  530277.37  183101.39  -0.123189
# 1       09/01/2016 12:00:00 AM  ...  529707.23  182682.77  -0.131558
# 2       07/01/2015 12:00:00 AM  ...  526716.88  184227.86  -0.174124
# 3       08/01/2017 12:00:00 AM  ...  530390.22  182860.71  -0.121652
# 4       06/01/2015 12:00:00 AM  ...  528335.87  186805.94  -0.149851
# ...                        ...  ...        ...        ...        ...
# 285102  12/01/2020 12:00:00 AM  ...  529587.23  182301.71  -0.133427
# 285103  07/01/2020 12:00:00 AM  ...  528245.25  184505.68  -0.151958
# 285104  08/01/2020 12:00:00 AM  ...  529978.23  181417.72  -0.128120
# 285105  04/01/2021 12:00:00 AM  ...  530354.22  181743.26  -0.122584
# 285106  03/01/2021 12:00:00 AM  ...  526340.28  185750.68  -0.178968
#
#          Latitude  Last Uploaded  count Category encoded  Ward encoded  \
# 0       51.531800     11/07/2018      1                6            15
# 1       51.528169     11/07/2018      1                0            15
# 2       51.542741     05/05/2016      1               11            16
# 3       51.529611     03/11/2017      1                0            13
# 4       51.565544     21/08/2015      1                4             9
# ...           ...            ...    ...              ...           ...
# 285102  51.524772     11/06/2021      1               11             1
# 285103  51.544885     11/06/2021      1                1             8
# 285104  51.516738     11/06/2021      1               11             1
# 285105  51.519577     11/06/2021      1               13            10
# 285106  51.556503     11/06/2021      1                0             5
#
#         Street ID encoded  Street name encoded
# 0                    1531                   39
# 1                     127                 1138
# 2                     821                   97
# 3                     416                  152
# 4                    1437                  819
# ...                   ...                  ...
# 285102                195                  442
# 285103                737                  312
# 285104                100                  798
# 285105               1540                 1197
# 285106               1094                  585
#
# [285107 rows x 22 columns]

# %%
df_crime_street_reduced = df_crime.drop(['Category', 'Outcome Category', 'Easting', 'Ward encoded','Northing', 'Category encoded', 'Longitude', 'Latitude', 'ID', 'Outcome Date', 'Service', 'Location Subtype',	'ID', 'Persistent ID', 'Epoch', 'Ward Code', 'Ward Name', 'Last Uploaded'], axis=1, )     #remove all other columns
df_crime_street_reduced.sort_values(by = 'Street ID')
# Out:
#         Street ID               Street Name  count  Street ID encoded  \
# 157062     587590            On or near A40      1                  0
# 63586      587590            On or near A40      1                  0
# 19936      587590            On or near A40      1                  0
# 88600      587590            On or near A40      1                  0
# 198482     587590            On or near A40      1                  0
# ...           ...                       ...    ...                ...
# 269338    1490647  West Hampstead (station)      1               1541
# 251244    1490652      Maidenhead (station)      1               1542
# 272710    1490652      Maidenhead (station)      1               1542
# 224075    1490652      Maidenhead (station)      1               1542
# 228285    1490652      Maidenhead (station)      1               1542
#
#         Street name encoded
# 157062                   47
# 63586                    47
# 19936                    47
# 88600                    47
# 198482                   47
# ...                     ...
# 269338                 1204
# 251244                   44
# 272710                   44
# 224075                   44
# 228285                   44
#
# [285107 rows x 5 columns]

# %% [markdown]
# # PMCC Matrix

# %%
df_cor_matrix = df_crime.drop(['count'], axis=1)

# %%
corr_matrix_crime = df_cor_matrix.corr()
corr_matrix_crime.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_897f4_row0_col0,#T_897f4_row1_col1,#T_897f4_row2_col2,#T_897f4_row2_col4,#T_897f4_row3_col3,#T_897f4_row3_col5,#T_897f4_row4_col2,#T_897f4_row4_col4,#T_897f4_row5_col3,#T_897f4_row5_col5,#T_897f4_row6_col6,#T_897f4_row7_col7,#T_897f4_row8_col8,#T_897f4_row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_897f4_row0_col1{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_897f4_row0_col2{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_897f4_row0_col3{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_897f4_row0_col4{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_897f4_row0_col5,#T_897f4_row9_col3{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_897f4_row0_col6,#T_897f4_row8_col2,#T_897f4_row8_col4{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_897f4_row0_col7{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_897f4_row0_col8{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_897f4_row0_col9,#T_897f4_row1_col6,#T_897f4_row2_col3,#T_897f4_row2_col5,#T_897f4_row2_col8,#T_897f4_row5_col2,#T_897f4_row5_col4,#T_897f4_row6_col1,#T_897f4_row9_col0,#T_897f4_row9_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_897f4_row1_col0{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_897f4_row1_col2,#T_897f4_row6_col5,#T_897f4_row7_col4{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_897f4_row1_col3,#T_897f4_row6_col2,#T_897f4_row9_col4{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_897f4_row1_col4,#T_897f4_row6_col3,#T_897f4_row7_col5{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_897f4_row1_col5,#T_897f4_row9_col2{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_897f4_row1_col7,#T_897f4_row7_col9{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_897f4_row1_col8{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_897f4_row1_col9{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_897f4_row2_col0,#T_897f4_row4_col0{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_897f4_row2_col1{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_897f4_row2_col6,#T_897f4_row4_col6{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_897f4_row2_col7,#T_897f4_row4_col7{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_897f4_row2_col9{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_897f4_row3_col0,#T_897f4_row5_col0{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_897f4_row3_col1,#T_897f4_row3_col7,#T_897f4_row5_col1,#T_897f4_row5_col7,#T_897f4_row7_col1,#T_897f4_row9_col6{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_897f4_row3_col2,#T_897f4_row3_col4{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_897f4_row3_col6,#T_897f4_row4_col1,#T_897f4_row5_col6,#T_897f4_row8_col9{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_897f4_row3_col8{
#             background-color:  #e67259;
#             color:  #000000;
#         }#T_897f4_row3_col9,#T_897f4_row5_col9,#T_897f4_row8_col6{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_897f4_row4_col3,#T_897f4_row4_col5,#T_897f4_row4_col8{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_897f4_row4_col9,#T_897f4_row6_col9{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_897f4_row5_col8{
#             background-color:  #e7745b;
#             color:  #000000;
#         }#T_897f4_row6_col0{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_897f4_row6_col4{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_897f4_row6_col7{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_897f4_row6_col8{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_897f4_row7_col0{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_897f4_row7_col2{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_897f4_row7_col3{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_897f4_row7_col6,#T_897f4_row9_col1{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_897f4_row7_col8,#T_897f4_row9_col5{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_897f4_row8_col0{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_897f4_row8_col1{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_897f4_row8_col3,#T_897f4_row8_col5{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_897f4_row8_col7{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_897f4_row9_col8{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }</style><table id="T_897f4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Street ID</th>        <th class="col_heading level0 col1" >ID</th>        <th class="col_heading level0 col2" >Easting</th>        <th class="col_heading level0 col3" >Northing</th>        <th class="col_heading level0 col4" >Longitude</th>        <th class="col_heading level0 col5" >Latitude</th>        <th class="col_heading level0 col6" >Category encoded</th>        <th class="col_heading level0 col7" >Ward encoded</th>        <th class="col_heading level0 col8" >Street ID encoded</th>        <th class="col_heading level0 col9" >Street name encoded</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_897f4_level0_row0" class="row_heading level0 row0" >Street ID</th>
#                         <td id="T_897f4_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_897f4_row0_col1" class="data row0 col1" >0.062728</td>
#                         <td id="T_897f4_row0_col2" class="data row0 col2" >0.116671</td>
#                         <td id="T_897f4_row0_col3" class="data row0 col3" >-0.053576</td>
#                         <td id="T_897f4_row0_col4" class="data row0 col4" >0.117169</td>
#                         <td id="T_897f4_row0_col5" class="data row0 col5" >-0.055920</td>
#                         <td id="T_897f4_row0_col6" class="data row0 col6" >0.111079</td>
#                         <td id="T_897f4_row0_col7" class="data row0 col7" >0.196558</td>
#                         <td id="T_897f4_row0_col8" class="data row0 col8" >0.471608</td>
#                         <td id="T_897f4_row0_col9" class="data row0 col9" >-0.152493</td>
#             </tr>
#             <tr>
#                         <th id="T_897f4_level0_row1" class="row_heading level0 row1" >ID</th>
#                         <td id="T_897f4_row1_col0" class="data row1 col0" >0.062728</td>
#                         <td id="T_897f4_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_897f4_row1_col2" class="data row1 col2" >-0.011883</td>
#                         <td id="T_897f4_row1_col3" class="data row1 col3" >0.016033</td>
#                         <td id="T_897f4_row1_col4" class="data row1 col4" >-0.011234</td>
#                         <td id="T_897f4_row1_col5" class="data row1 col5" >0.015879</td>
#                         <td id="T_897f4_row1

# %%
df_crime.shape
# Out:
# (285107, 22)

# %%
# export the 'cleaned' df_crime dataframe as a csv file 
df_crime.to_csv('df_crime_cleaned.csv', index=False)
